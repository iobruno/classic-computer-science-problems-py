# %% [markdown]
# # Domain Definitions

# %%
import pandas as pd
import random
from dataclasses import dataclass
from numpy.random import default_rng
from numpy.random import Generator
from pathlib import Path
from typing import Optional, List, Set, Dict, Tuple

# %%
@dataclass(frozen=True)
class Item:
    name: str
    value: float
    weight: int
    time_to_steal: int

    @property
    def tts(self):
        return self.time_to_steal

# %%
@dataclass(frozen=False)
class Node:
    name: str
    item: Item

    def __init__(self, name: str):
        self.name = name
        self.item = None

    def with_item(self, name: str, value: float, weight, tts: int) -> 'Node':
        return self._with_item(Item(name, value, weight, time_to_steal=tts))

    def _with_item(self, item: Item) -> 'Node':
        self.item = item
        return self

    def to_dict(self):
        try:
            return {
                'name': self.name,
                'item': self.item.name,
                'value': self.item.value,
                'weight': self.item.weight,
                'tts': self.item.tts
            }
        except Exception:
            return {
                'name': self.name,
                'item': None,
            }

    def __hash__(self) -> int:
        return self.name.__hash__()

# %%
@dataclass(frozen=True)
class Edge:
    source: Node
    destination: Node
    travelling_time: int
    travelling_cost: float

    @property
    def time(self):
        return self.travelling_time

    @property
    def cost(self):
        return self.travelling_cost

    def to_dict(self):
        return {
            'source': self.source.name,
            'destination': self.destination.name,
            'travelling_time': self.time,
            'travelling_cost': self.cost
        }

# %%
class Graph:
    nodes: Dict[str, Node]
    edges: Dict[Tuple[Node, Node], Edge]
    connections: Dict[Node, Set[Edge]]

    def __init__(self):
        self.nodes = dict()
        self.edges = dict()
        self.connections = dict()

    def get_node(self, name: str) -> Optional[Node]:
        return self.nodes.get(name)

    def get_all_nodes(self) -> List[Node]:
        return list(self.nodes.values())

    def get_all_edges(self) -> List[Edge]:
        return list(self.edges.values())

    def get_connections_from_node(self, node: Node) -> List[Edge]:
        return self.connections.get(node, {})

    def get_connections_from(self, node_name: str) -> List[Edge]:
        node: Optional[Node] = self.get_node(node_name)
        return self.get_connections_from_node(node)

    def find_connection_between(self, src: Node, dst: Node) -> Optional[Edge]:
        return self.edges.get((src, dst), None)

    def add_edge(self, src: str, dst: str, tt: int, tc: float) -> 'Graph':
        source = self.nodes.get(src, Node(src))
        destination = self.nodes.get(dst, Node(dst))
        edge = Edge(source, destination, travelling_time=tt, travelling_cost=tc)
        self._add_node(source)._add_node(destination)
        self.edges[(source, destination)] = edge
        self.connections[source] = self.connections.get(source, []) + [edge]
        return self

    def add_node(self, node_name: str) -> 'Graph':
        self.nodes[node_name] = Node(node_name)
        return self

    def _add_node(self, node: Node) -> 'Graph':
        self.nodes[node.name] = node
        return self

# %% [markdown]
# # Graph Construction

# %%
datasets_dir = Path().absolute().joinpath('datasets')
travelling_map = f"{datasets_dir}/travelling_map.csv"
treasure_map = f"{datasets_dir}/treasure_map.csv"

# %%
travels = pd.read_csv(travelling_map)
treasures = pd.read_csv(treasure_map)

# %%
g = Graph()

# %%
travels.apply(lambda row: g.add_edge(src=row['source'],
                                     dst=row['destination'],
                                     tt=row['travelling_time'],
                                     tc=row['travelling_cost'])
                           .add_edge(src=row['destination'],
                                     dst=row['source'],
                                     tt=row['travelling_time'],
                                     tc=row['travelling_cost']), axis=1)

treasures.apply(lambda row: g.get_node(row['city'])
                             .with_item(row['name'],
                                        row['value'],
                                        row['weight'],
                                        row['tts']), axis=1);

# %% [markdown]
# # Problem Solving

# %%
@dataclass(frozen=False)
class Individual:
    genes: List[Node]
    extra_genes: List[Node]
    total_income: float
    travelling_cost: float
    traveling_time: int
    time_to_steal: int
    carry_weight: int
    generation: int

    @property
    def profit(self):
        return self.total_income - self.travelling_cost

    @property
    def total_time(self):
        return self.traveling_time + self.time_to_steal

    @property
    def score(self):
        return self.profit/self.total_time

    def pretty_print(self):
        names: List[str] = [gene.name for gene in self.genes]
        path: str = " -> ".join(names)
        print(f"""
        Path: {path}
        Profit: {self.profit}
        Total time: {self.total_time}
        Score: {self.score}
        Generation: {self.generation}""")

    def __eq__(self, other):
        try:
            return self.genes == other.genes
        except Exception:
            return False

    def __hash__(self):
        return sum([n.__hash__() for n in self.genes])

# %%
class GeneticAlgorithm:
    graph: Graph
    genes: Set[Node]
    max_hours: int
    max_weight: int
    rng: Generator

    def __init__(self, graph: Graph, with_max_hours: int, with_max_weight: int):
        self.graph = graph
        self.genes = list(graph.get_all_nodes())
        self.max_hours = with_max_hours
        self.max_weight = with_max_weight
        self.rng = default_rng()

    def generate_initial_batch(self, size: int = 10) -> List[Individual]:
        length = len(self.genes)
        return [self._generate_individual(length) for i in range(size)]

    def _generate_individual(self, number_of_genes: int):
        while True:
            genes, extra_genes = self._generate_individual_genes(number_of_genes)
            indv: Individual = self.generate_individual_with(genes=genes, extra_genes=extra_genes)

            if indv == None:
                continue

            if self.fitness(indv) > 0:
                return indv

    def _generate_individual_genes(self, number: int) -> Tuple[List[Node], List[Node]]:
        indexes: List[int] = self.rng.choice(number, size=number, replace=False)
        genes: List[Node] = [self.genes[idx] for idx in indexes]

        starting_point: Node = self.graph.get_node("Escondidos")
        endpoint_idx: int = genes.index(starting_point)

        individual_genes: List[Node] = [starting_point] + genes[0:endpoint_idx+1]
        extra_genes: List[Node] = genes[endpoint_idx+1:]
        return individual_genes, extra_genes

    def generate_individual_with(self, genes, extra_genes, generation: int = 0):
        tuples: List[Tuple[Node, Node]] = [(genes[idx], genes[num]) for idx, num in enumerate(range(1, len(genes)))]
        connections: List[Edge] = [self.graph.find_connection_between(src, dest) for src, dest in tuples if (src != dest)]

        if len(connections) == 0:
            return None

        travelling_cost: float = 0.0
        travelling_time: int = 0
        total_income: float = 0.0
        time_to_steal: int = 0
        total_weight: int = 0

        for cx in connections:
            travelling_cost += cx.travelling_cost
            travelling_time += cx.travelling_time
            total_income += cx.destination.to_dict().get('value', 0)
            time_to_steal += cx.destination.to_dict().get('tts', 0)
            total_weight += cx.destination.to_dict().get('weight', 0)

        indv = Individual(genes, total_income=total_income, time_to_steal=time_to_steal,
                          travelling_cost=travelling_cost, traveling_time=travelling_time,
                          carry_weight=total_weight, extra_genes=extra_genes,
                          generation=generation)
        return indv


    def fitness(self, indv: Individual) -> int:
        if indv.carry_weight > self.max_weight or indv.total_time > self.max_hours:
            return 0

        return indv.score

    def mutate(self, indv: Individual) -> Optional[Individual]:
        left: List[Node] = list(indv.genes)
        right: List[Node] = list(indv.extra_genes)

        left_idx: int = random.randint(1, len(left)-2)
        right_idx: int = random.randint(0, len(right)-1)

        tmp = left[left_idx]
        left[left_idx] = right[right_idx]
        right[right_idx] = tmp

        new_indv = self.generate_individual_with(genes=left, 
                                                 extra_genes=right, 
                                                 generation=indv.generation+1)
        if self.fitness(new_indv) > 0:
            return new_indv

        return None


    def cross_over(self, indvA: Individual, indvB: Individual) -> List[Individual]:
        if indvA is None or indvB is None:
            return []

        gene = [self.graph.get_node('Escondidos')]
        next_gen = max(indvA.generation, indvB.generation)+1

        indvC = self.generate_individual_with(genes=list(gene + indvB.extra_genes + gene),
                                              extra_genes=list(indvA.genes[1:-1]),
                                              generation = next_gen)

        indvD = self.generate_individual_with(genes=list(gene + indvA.extra_genes + gene),
                                              extra_genes=list(indvA.genes[1:-1]), 
                                              generation = next_gen)

        cross_over_population = list()

        if self.fitness(indvC) > 0:
            cross_over_population.append(indvC)

        if self.fitness(indvD) > 0:
            cross_over_population.append(indvC)

        return cross_over_population

# %%
ga = GeneticAlgorithm(g, with_max_hours=72, with_max_weight=20)

# %%
population = ga.generate_initial_batch(size=100)

# %%
for i in range(10):
    new_population = list()

    for idx, indv in enumerate(population[:-1]):
        a = indv
        b = population[idx+1]
        a_mut = ga.mutate(a)
        b_mut = ga.mutate(b)

        new_population += ga.cross_over(a, b)
        new_population += ga.cross_over(a, b_mut)
        new_population += ga.cross_over(a_mut, b)
        new_population += ga.cross_over(a_mut, b_mut)

    population += new_population
    population = sorted(set(population), key=lambda indv: indv.score, reverse=True)

# %%
len(population)
# Out:
# 785

# %%
for p in population[0:100]:
    p.pretty_print()
# Out:
#         Path: Escondidos -> Riacho de Fevereiro -> Escondidos
#         Profit: 6870.0
#         Total time: 8
#         Score: 858.75
#         Generation: 0
#
#         Path: Escondidos -> Leão -> Guardião -> Ponte-do-Sol -> Campos -> Granada -> Porto -> Riacho de Fevereiro -> Escondidos
#         Profit: 25472.0
#         Total time: 41
#         Score: 621.2682926829268
#         Generation: 9
#
#         Path: Escondidos -> Leão -> Guardião -> Santa Paula -> Campos -> Granada -> Porto -> Riacho de Fevereiro -> Escondidos
#         Profit: 33201.0
#         Total time: 56
#         Score: 592.875
#         Generation: 4
#
#         Path: Escondidos -> Riacho de Fevereiro -> Lagos -> Campos -> Escondidos
#         Profit: 15716.0
#         Total time: 29
#         Score: 541.9310344827586
#         Generation: 12
#
#         Path: Escondidos -> Limões -> Limões -> Riacho de Fevereiro -> Porto -> Granada -> Campos -> Lagos -> Leão -> Escondidos
#         Profit: 27517.0
#         Total time: 51
#         Score: 539.5490196078431
#         Generation: 8
#
#         Path: Escondidos -> Leão -> Guardião -> Santa Paula -> Campos -> Leão -> Além-do-Mar -> Riacho de Fevereiro -> Escondidos
#         Profit: 37801.0
#         Total time: 71
#         Score: 532.4084507042254
#         Generation: 9
#
#         Path: Escondidos -> Santa Paula -> Santa Paula -> Ponte-do-Sol -> Leão -> Granada -> Leão -> Riacho de Fevereiro -> Escondidos
#         Profit: 26817.0
#         Total time: 51
#         Score: 525.8235294117648
#         Generation: 9
#
#         Path: Escondidos -> Leão -> Guardião -> Santa Paula -> Campos -> Santa Paula -> Além-do-Mar -> Riacho de Fevereiro -> Escondidos
#         Profit: 42948.0
#         Total time: 82
#         Score: 523.7560975609756
#         Generation: 12
#
#         Path: Escondidos -> Leão -> Guardião -> Ponte-do-Sol -> Leão -> Granada -> Lagos -> Riacho de Fevereiro -> Escondidos
#         Profit: 23950.0
#         Total time: 46
#         Score: 520.6521739130435
#         Generation: 5
#
#         Path: Escondidos -> Leão -> Guardião -> Santa Paula -> Campos -> Além-do-Mar -> Porto -> Riacho de Fevereiro -> Escondidos
#         Profit: 35751.0
#         Total time: 69
#         Score: 518.1304347826087
#         Generation: 9
#
#         Path: Escondidos -> Riacho de Fevereiro -> Campos -> Granada -> Escondidos
#         Profit: 14400.0
#         Total time: 28
#         Score: 514.2857142857143
#         Generation: 9
#
#         Path: Escondidos -> Campos -> Santa Paula -> Lagos -> Riacho de Fevereiro -> Escondidos
#         Profit: 24968.0
#         Total time: 49
#         Score: 509.55102040816325
#         Generation: 13
#
#         Path: Escondidos -> Santa Paula -> Guardião -> Leão -> Leão -> Granada -> Lagos -> Riacho de Fevereiro -> Escondidos
#         Profit: 27405.0
#         Total time: 54
#         Score: 507.5
#         Generation: 5
#
#         Path: Escondidos -> Santa Paula -> Guardião -> Guardião -> Leão -> Granada -> Lagos -> Riacho de Fevereiro -> Escondidos
#         Profit: 27405.0
#         Total time: 54
#         Score: 507.5
#         Generation: 8
#
#         Path: Escondidos -> Leão -> Riacho de Fevereiro -> Santa Paula -> Campos -> Granada -> Além-do-Mar -> Riacho de Fevereiro -> Escondidos
#         Profit: 38781.0
#         Total time: 77
#         Score: 503.64935064935065
#         Generation: 10
#
#         Path: Escondidos -> Leão -> Guardião -> Santa Paula -> Campos -> Granada -> Além-do-Mar -> Riacho de Fevereiro -> Escondidos
#         Profit: 35756.0
#         Total time: 71
#         Score: 503.6056338028169
#         Generation: 1
#
#         Path: Escondidos -> Campos -> Santa Paula -> Porto -> Limões -> Granada -> Leão -> Além-do-Mar -> Riacho de Fevereiro -> Escondidos
#         Profit: 39025.0
#         Total time: 78
#         Score: 500.3205128205128
#         Generation: 4
#
#         Path: Escondidos -> Porto -> Campos -> Santa Paula -> Porto -> Riacho de Fevereiro -> Escondidos
#         Profit: 25510.0
#         Total time: 51
#         Score: 500.19607843137254
#         Generation: 6
#
#         Path: Escondidos -> Leão -> Guardião -> Santa Paula -> Campos -> Riacho de Fevereiro -> Além-do-Mar -> Riacho de Fevereiro -> Escondidos
#         Profit: 39944.0
#         Total time: 80
#         Score: 499.3
#         Generation: 10
#
#         Path: Escondidos -> Campos -> Santa Paula -> Escondidos
#         Profit: 14966.0
#         Total time: 30
#         Score: 498.8666666666667
#         Generation: 10
#
#         Path: Escondidos -> Santa Paula -> Campos -> Santa Paula -> Guardião -> Riacho de Fevereiro -> Escondidos
#         Profit: 33404.0
#         Total time: 67
#         Score: 498.56716417910445
#         Generation: 6
#
#         Path: Escondidos -> Riacho de Fevereiro -> Porto -> Escondidos
#         Profit: 8451.0
#         Total time: 17
#         Score: 497.11764705882354
#         Generation: 7
#
#         Path: Escondidos -> Santa Paula -> Santa Paula -> Ponte-do-Sol -> Leão -> Granada -> Lagos -> Riacho de Fevereiro -> Escondidos
#         Profit: 26100.0
#         Total time: 53
#         Score: 492.45283018867923
#         Generation: 9
#
#         Path: Escondidos -> Santa Paula -> Guardião -> Ponte-do-Sol -> Leão -> Granada -> Leão -> Riacho de Fevereiro -> Escondidos
#         Profit: 29440.0
#         Total time: 60
#         Score: 490.6666666666667
#         Generation: 5
#
#         Path: Escondidos -> Leão -> Guardião -> Santa Paula -> Campos -> Granada -> Porto -> Granada -> Escondidos
#         Profit: 28276.0
#         Total time: 58
#         Score: 487.51724137931035
#         Generation: 9
#
#         Path: Escondidos -> Leão -> Guardião -> Santa Paula -> Foz da Água Quente -> Granada -> Porto -> Riacho de Fevereiro -> Escondidos
#         Profit: 28631.0
#         Total time: 59
#         Score: 485.271186440678
#         Generation: 9
#
#         Path: Escondidos -> Santa Paula -> Riacho de Fevereiro -> Escondidos
#         Profit: 14963.0
#         Total time: 31
#         Score: 482.6774193548387
#         Generation: 5
#
#         Path: Escondidos -> Limões -> Além-do-Mar -> Riacho de Fevereiro -> Porto -> Granada -> Campos -> Lagos -> Leão -> Escondidos
#         Profit: 32242.0
#         Total time: 67
#         Score: 481.2238805970149
#         Generation: 3
#
#         Path: Escondidos -> Leão -> Guardião -> Santa Paula -> Campos -> Ponte-do-Sol -> Além-do-Mar -> Riacho de Fevereiro -> Escondidos
#         Profit: 35048.0
#         Total time: 73
#         Score: 480.1095890410959
#         Generation: 4
#
#         Path: Escondidos -> Santa Paula -> Guardião -> Ponte-do-Sol -> Lagos -> Granada -> Campos -> Riacho de Fevereiro -> Escondidos
#         Profit: 30462.0
#         Total time: 64
#         Score: 475.96875
#         Generation: 15
#
#         Path: Escondidos -> Riacho de Fevereiro -> Santa Paula -> Granada -> Escondidos
#         Profit: 17582.0
#         Total time: 37
#         Score: 475.18918918918916
#         Generation: 0
#
#         Path: Escondidos -> Santa Paula -> Guardião -> Ponte-do-Sol -> Leão -> Granada -> Limões -> Riacho de Fevereiro -> Escondidos
#         Profit: 29324.0
#         Total time: 63
#         Score: 465.46031746031747
#         Generation: 8
#
#         Path: Escondidos -> Leão -> Guardião -> Santa Paula -> Campos -> Algas -> Além-do-Mar -> Riacho de Fevereiro -> Escondidos
#         Profit: 35823.0
#         Total time: 77
#         Score: 465.23376623376623
#         Generation: 4
#
#         Path: Escondidos -> Santa Paula -> Guardião -> Ponte-do-Sol -> Leão -> Granada -> Lagos -> Riacho de Fevereiro -> Escondidos
#         Profit: 28723.0
#         Total time: 62
#         Score: 463.2741935483871
#         Generation: 2
#
#         Path: Escondidos -> Leão -> Guardião -> Guardião -> Campos -> Riacho de Fevereiro -> Além-do-Mar -> Riacho de Fevereiro -> Escondidos
#         Profit: 30097.0
#         Total time: 65
#         Score: 463.03076923076924
#         Generation: 14
#
#         Path: Escondidos -> Leão -> Guardião -> Santa Paula -> Campos -> Granada -> Guardião -> Riacho de Fevereiro -> Escondidos
#         Profit: 32868.0
#         Total time: 71
#         Score: 462.92957746478874
#         Generation: 10
#
#         Path: Escondidos -> Santa Paula -> Foz da Água Quente -> Ponte-do-Sol -> Leão -> Granada -> Lagos -> Riacho de Fevereiro -> Escondidos
#         Profit: 27692.0
#         Total time: 60
#         Score: 461.53333333333336
#         Generation: 5
#
#         Path: Escondidos -> Além-do-Mar -> Lagos -> Leão -> Riacho de Fevereiro -> Porto -> Santa Paula -> Escondidos
#         Profit: 29075.0
#         Total time: 63
#         Score: 461.5079365079365
#         Generation: 7
#
#         Path: Escondidos -> Leão -> Guardião -> Santa Paula -> Campos -> Porto -> Granada -> Riacho de Fevereiro -> Escondidos
#         Profit: 31782.0
#         Total time: 69
#         Score: 460.60869565217394
#         Generation: 9
#
#         Path: Escondidos -> Campos -> Santa Paula -> Porto -> Limões -> Granada -> Leão -> Algas -> Riacho de Fevereiro -> Escondidos
#         Profit: 35732.0
#         Total time: 78
#         Score: 458.1025641025641
#         Generation: 4
#
#         Path: Escondidos -> Campos -> Santa Paula -> Lagos -> Leão -> Escondidos
#         Profit: 21901.0
#         Total time: 48
#         Score: 456.2708333333333
#         Generation: 9
#
#         Path: Escondidos -> Foz da Água Quente -> Limões -> Granada -> Lagos -> Além-do-Mar -> Leão -> Granada -> Leão -> Escondidos
#         Profit: 25525.0
#         Total time: 56
#         Score: 455.80357142857144
#         Generation: 15
#
#         Path: Escondidos -> Porto -> Granada -> Limões -> Algas -> Campos -> Leão -> Riacho de Fevereiro -> Escondidos
#         Profit: 25859.0
#         Total time: 57
#         Score: 453.6666666666667
#         Generation: 10
#
#         Path: Escondidos -> Ponte-do-Sol -> Campos -> Leão -> Guardião -> Porto -> Riacho de Fevereiro -> Escondidos
#         Profit: 22570.0
#         Total time: 50
#         Score: 451.4
#         Generation: 11
#
#         Path: Escondidos -> Riacho de Fevereiro -> Lagos -> Santa Paula -> Escondidos
#         Profit: 18442.0
#         Total time: 41
#         Score: 449.8048780487805
#         Generation: 9
#
#         Path: Escondidos -> Santa Paula -> Limões -> Foz da Água Quente -> Campos -> Leão -> Riacho de Fevereiro -> Leão -> Escondidos
#         Profit: 33625.0
#         Total time: 75
#         Score: 448.3333333333333
#         Generation: 7
#
#         Path: Escondidos -> Santa Paula -> Guardião -> Ponte-do-Sol -> Leão -> Lagos -> Lagos -> Riacho de Fevereiro -> Escondidos
#         Profit: 26372.0
#         Total time: 59
#         Score: 446.9830508474576
#         Generation: 5
#
#         Path: Escondidos -> Leão -> Guardião -> Ponte-do-Sol -> Granada -> Porto -> Santa Paula -> Riacho de Fevereiro -> Além-do-Mar -> Além-do-Mar -> Campos -> Escondidos
#         Profit: 38267.0
#         Total time: 86
#         Score: 444.9651162790698
#         Generation: 12
#
#         Path: Escondidos -> Ponte-do-Sol -> Guardião -> Leão -> Santa Paula -> Porto -> Riacho de Fevereiro -> Escondidos
#         Profit: 25787.0
#         Total time: 58
#         Score: 444.6034482758621
#         Generation: 1
#
#         Path: Escondidos -> Lagos -> Santa Paula -> Santa Paula -> Campos -> Granada -> Além-do-Mar -> Riacho de Fevereiro -> Escondidos
#         Profit: 31508.0
#         Total time: 71
#         Score: 443.77464788732397
#         Generation: 9
#
#         Path: Escondidos -> Lagos -> Granada -> Limões -> Algas -> Campos -> Leão -> Riacho de Fevereiro -> Escondidos
#         Profit: 26571.0
#         Total time: 60
#         Score: 442.85
#         Generation: 10
#
#         Path: Escondidos -> Ponte-do-Sol -> Guardião -> Leão -> Guardião -> Porto -> Riacho de Fevereiro -> Escondidos
#         Profit: 19422.0
#         Total time: 44
#         Score: 441.40909090909093
#         Generation: 8
#
#         Path: Escondidos -> Porto -> Campos -> Santa Paula -> Santa Paula -> Riacho de Fevereiro -> Escondidos
#         Profit: 22498.0
#         Total time: 51
#         Score: 441.1372549019608
#         Generation: 6
#
#         Path: Escondidos -> Leão -> Guardião -> Lagos -> Campos -> Granada -> Além-do-Mar -> Riacho de Fevereiro -> Escondidos
#         Profit: 29082.0
#         Total time: 66
#         Score: 440.6363636363636
#         Generation: 10
#
#         Path: Escondidos -> Santa Paula -> Guardião -> Ponte-do-Sol -> Lagos -> Granada -> Lagos -> Riacho de Fevereiro -> Escondidos
#         Profit: 27709.0
#         Total time: 63
#         Score: 439.8253968253968
#         Generation: 5
#
#         Path: Escondidos -> Santa Paula -> Lagos -> Ponte-do-Sol -> Leão -> Granada -> Lagos -> Riacho de Fevereiro -> Escondidos
#         Profit: 28848.0
#         Total time: 66
#         Score: 437.09090909090907
#         Generation: 5
#
#         Path: Escondidos -> Campos -> Guardião -> Ponte-do-Sol -> Lagos -> Granada -> Lagos -> Riacho de Fevereiro -> Escondidos
#         Profit: 24388.0
#         Total time: 56
#         Score: 435.5
#         Generation: 8
#
#         Path: Escondidos -> Santa Paula -> Guardião -> Ponte-do-Sol -> Leão -> Granada -> Granada -> Riacho de Fevereiro -> Escondidos
#         Profit: 25242.0
#         Total time: 58
#         Score: 435.2068965517241
#         Generation: 13
#
#         Path: Escondidos -> Leão -> Guardião -> Santa Paula -> Campos -> Porto -> Além-do-Mar -> Riacho de Fevereiro -> Escondidos
#         Profit: 34652.0
#         Total time: 80
#         Score: 433.15
#         Generation: 4
#
#         Path: Escondidos -> Campos -> Santa Paula -> Guardião -> Limões -> Granada -> Leão -> Algas -> Riacho de Fevereiro -> Escondidos
#         Profit: 35484.0
#         Total time: 82
#         Score: 432.7317073170732
#         Generation: 7
#
#         Path: Escondidos -> Porto -> Guardião -> Santa Paula -> Campos -> Granada -> Além-do-Mar -> Riacho de Fevereiro -> Escondidos
#         Profit: 33223.0
#         Total time: 77
#         Score: 431.46753246753246
#         Generation: 12
#
#         Path: Escondidos -> Riacho de Fevereiro -> Lagos -> Granada -> Escondidos
#         Profit: 11647.0
#         Total time: 27
#         Score: 431.3703703703704
#         Generation: 5
#
#         Path: Escondidos -> Porto -> Campos -> Santa Paula -> Além-do-Mar -> Riacho de Fevereiro -> Escondidos
#         Profit: 27950.0
#         Total time: 65
#         Score: 430.0
#         Generation: 10
#
#         Path: Escondidos -> Santa Paula -> Ponte-do-Sol -> Riacho de Fevereiro -> Escondidos
#         Profit: 16334.0
#         Total time: 38
#         Score: 429.8421052631579
#         Generation: 4
#
#         Path: Escondidos -> Santa Paula -> Riacho de Fevereiro -> Riacho de Fevereiro -> Porto -> Guardião -> Campos -> Lagos -> Leão -> Escondidos
#         Profit: 31768.0
#         Total time: 74
#         Score: 429.2972972972973
#         Generation: 14
#
#         Path: Escondidos -> Leão -> Guardião -> Santa Paula -> Santa Paula -> Algas -> Além-do-Mar -> Riacho de Fevereiro -> Escondidos
#         Profit: 29726.0
#         Total time: 70
#         Score: 424.65714285714284
#         Generation: 7
#
#         Path: Escondidos -> Porto -> Campos -> Santa Paula -> Leão -> Riacho de Fevereiro -> Escondidos
#         Profit: 26324.0
#         Total time: 62
#         Score: 424.5806451612903
#         Generation: 10
#
#         Path: Escondidos -> Santa Paula -> Guardião -> Lagos -> Leão -> Granada -> Lagos -> Riacho de Fevereiro -> Escondidos
#         Profit: 29715.0
#         Total time: 70
#         Score: 424.5
#         Generation: 9
#
#         Path: Escondidos -> Algas -> Porto -> Santa Paula -> Riacho de Fevereiro -> Campos -> Além-do-Mar -> Granada -> Leão -> Guardião -> Riacho de Fevereiro -> Escondidos
#         Profit: 44959.0
#         Total time: 106
#         Score: 424.14150943396226
#         Generation: 9
#
#         Path: Escondidos -> Guardião -> Leão -> Campos -> Algas -> Limões -> Escondidos
#         Profit: 17804.0
#         Total time: 42
#         Score: 423.9047619047619
#         Generation: 4
#
#         Path: Escondidos -> Santa Paula -> Além-do-Mar -> Riacho de Fevereiro -> Porto -> Guardião -> Campos -> Lagos -> Leão -> Escondidos
#         Profit: 37220.0
#         Total time: 88
#         Score: 422.95454545454544
#         Generation: 3
#
#         Path: Escondidos -> Leão -> Guardião -> Porto -> Campos -> Granada -> Além-do-Mar -> Riacho de Fevereiro -> Escondidos
#         Profit: 27681.0
#         Total time: 66
#         Score: 419.40909090909093
#         Generation: 10
#
#         Path: Escondidos -> Santa Paula -> Guardião -> Ponte-do-Sol -> Leão -> Guardião -> Além-do-Mar -> Riacho de Fevereiro -> Escondidos
#         Profit: 30867.0
#         Total time: 74
#         Score: 417.1216216216216
#         Generation: 12
#
#         Path: Escondidos -> Porto -> Campos -> Ponte-do-Sol -> Santa Paula -> Riacho de Fevereiro -> Escondidos
#         Profit: 23760.0
#         Total time: 57
#         Score: 416.8421052631579
#         Generation: 9
#
#         Path: Escondidos -> Leão -> Guardião -> Ponte-do-Sol -> Granada -> Porto -> Santa Paula -> Riacho de Fevereiro -> Algas -> Além-do-Mar -> Campos -> Escondidos
#         Profit: 40202.0
#         Total time: 97
#         Score: 414.45360824742266
#         Generation: 2
#
#         Path: Escondidos -> Foz da Água Quente -> Limões -> Granada -> Lagos -> Além-do-Mar -> Lagos -> Granada -> Leão -> Escondidos
#         Profit: 24423.0
#         Total time: 59
#         Score: 413.9491525423729
#         Generation: 15
#
#         Path: Escondidos -> Santa Paula -> Guardião -> Ponte-do-Sol -> Leão -> Guardião -> Lagos -> Riacho de Fevereiro -> Escondidos
#         Profit: 28856.0
#         Total time: 70
#         Score: 412.22857142857146
#         Generation: 5
#
#         Path: Escondidos -> Lagos -> Riacho de Fevereiro -> Escondidos
#         Profit: 9059.0
#         Total time: 22
#         Score: 411.77272727272725
#         Generation: 8
#
#         Path: Escondidos -> Porto -> Campos -> Santa Paula -> Ponte-do-Sol -> Riacho de Fevereiro -> Escondidos
#         Profit: 23869.0
#         Total time: 58
#         Score: 411.5344827586207
#         Generation: 6
#
#         Path: Escondidos -> Campos -> Santa Paula -> Lagos -> Granada -> Escondidos
#         Profit: 20147.0
#         Total time: 49
#         Score: 411.16326530612247
#         Generation: 0
#
#         Path: Escondidos -> Riacho de Fevereiro -> Santa Paula -> Guardião -> Escondidos
#         Profit: 17210.0
#         Total time: 42
#         Score: 409.76190476190476
#         Generation: 5
#
#         Path: Escondidos -> Campos -> Santa Paula -> Porto -> Além-do-Mar -> Lagos -> Escondidos
#         Profit: 24541.0
#         Total time: 60
#         Score: 409.01666666666665
#         Generation: 0
#
#         Path: Escondidos -> Ponte-do-Sol -> Riacho de Fevereiro -> Leão -> Santa Paula -> Campos -> Riacho de Fevereiro -> Escondidos
#         Profit: 31902.0
#         Total time: 78
#         Score: 409.0
#         Generation: 11
#
#         Path: Escondidos -> Limões -> Além-do-Mar -> Riacho de Fevereiro -> Porto -> Guardião -> Campos -> Lagos -> Leão -> Escondidos
#         Profit: 31874.0
#         Total time: 78
#         Score: 408.64102564102564
#         Generation: 3
#
#         Path: Escondidos -> Além-do-Mar -> Riacho de Fevereiro -> Escondidos
#         Profit: 11440.0
#         Total time: 28
#         Score: 408.57142857142856
#         Generation: 0
#
#         Path: Escondidos -> Campos -> Santa Paula -> Porto -> Limões -> Algas -> Leão -> Algas -> Riacho de Fevereiro -> Escondidos
#         Profit: 35501.0
#         Total time: 87
#         Score: 408.0574712643678
#         Generation: 7
#
#         Path: Escondidos -> Campos -> Santa Paula -> Porto -> Ponte-do-Sol -> Santa Paula -> Leão -> Algas -> Riacho de Fevereiro -> Escondidos
#         Profit: 39571.0
#         Total time: 97
#         Score: 407.9484536082474
#         Generation: 9
#
#         Path: Escondidos -> Limões -> Riacho de Fevereiro -> Santa Paula -> Campos -> Ponte-do-Sol -> Algas -> Guardião -> Leão -> Granada -> Lagos -> Além-do-Mar -> Foz da Água Quente -> Escondidos
#         Profit: 46470.0
#         Total time: 114
#         Score: 407.63157894736844
#         Generation: 8
#
#         Path: Escondidos -> Foz da Água Quente -> Guardião -> Santa Paula -> Campos -> Granada -> Além-do-Mar -> Riacho de Fevereiro -> Escondidos
#         Profit: 32581.0
#         Total time: 80
#         Score: 407.2625
#         Generation: 4
#
#         Path: Escondidos -> Ponte-do-Sol -> Lagos -> Leão -> Santa Paula -> Porto -> Riacho de Fevereiro -> Escondidos
#         Profit: 25644.0
#         Total time: 63
#         Score: 407.04761904761904
#         Generation: 3
#
#         Path: Escondidos -> Lagos -> Guardião -> Santa Paula -> Campos -> Granada -> Além-do-Mar -> Riacho de Fevereiro -> Escondidos
#         Profit: 33724.0
#         Total time: 83
#         Score: 406.31325301204816
#         Generation: 4
#
#         Path: Escondidos -> Limões -> Santa Paula -> Porto -> Limões -> Granada -> Leão -> Algas -> Riacho de Fevereiro -> Escondidos
#         Profit: 32875.0
#         Total time: 81
#         Score: 405.8641975308642
#         Generation: 7
#
#         Path: Escondidos -> Guardião -> Limões -> Foz da Água Quente -> Campos -> Leão -> Riacho de Fevereiro -> Leão -> Escondidos
#         Profit: 26327.0
#         Total time: 65
#         Score: 405.03076923076924
#         Generation: 4
#
#         Path: Escondidos -> Leão -> Guardião -> Lagos -> Campos -> Algas -> Além-do-Mar -> Riacho de Fevereiro -> Escondidos
#         Profit: 29149.0
#         Total time: 72
#         Score: 404.84722222222223
#         Generation: 8
#
#         Path: Escondidos -> Guardião -> Granada -> Limões -> Algas -> Campos -> Leão -> Riacho de Fevereiro -> Escondidos
#         Profit: 25900.0
#         Total time: 64
#         Score: 404.6875
#         Generation: 1
#
#         Path: Escondidos -> Campos -> Santa Paula -> Além-do-Mar -> Lagos -> Riacho de Fevereiro -> Leão -> Foz da Água Quente -> Porto -> Escondidos
#         Profit: 36015.0
#         Total time: 89
#         Score: 404.6629213483146
#         Generation: 9
#
#         Path: Escondidos -> Ponte-do-Sol -> Guardião -> Leão -> Santa Paula -> Porto -> Santa Paula -> Escondidos
#         Profit: 27912.0
#         Total time: 69
#         Score: 404.5217391304348
#         Generation: 8
#
#         Path: Escondidos -> Ponte-do-Sol -> Santa Paula -> Leão -> Guardião -> Porto -> Riacho de Fevereiro -> Escondidos
#         Profit: 25336.0
#         Total time: 63
#         Score: 402.1587301587302
#         Generation: 11
#
#         Path: Escondidos -> Ponte-do-Sol -> Campos -> Santa Paula -> Guardião -> Riacho de Fevereiro -> Escondidos
#         Profit: 25332.0
#         Total time: 63
#         Score: 402.0952380952381
#         Generation: 6
#
#         Path: Escondidos -> Ponte-do-Sol -> Riacho de Fevereiro -> Leão -> Santa Paula -> Porto -> Riacho de Fevereiro -> Escondidos
#         Profit: 28454.0
#         Total time: 71
#         Score: 400.76056338028167
#         Generation: 8
