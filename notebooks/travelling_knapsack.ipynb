# %% [markdown]
# # Domain Definitions

# %%
import pandas as pd
import random
from dataclasses import dataclass
from numpy.random import default_rng
from numpy.random import Generator
from pathlib import Path
from typing import Optional, List, Set, Dict, Tuple

# %%
@dataclass(frozen=True)
class Item:
    name: str
    value: float
    weight: int
    time_to_steal: int

    @property
    def tts(self):
        return self.time_to_steal

# %%
@dataclass(frozen=False)
class Node:
    name: str
    item: Item

    def __init__(self, name: str):
        self.name = name
        self.item = None

    def with_item(self, name: str, value: float, weight, tts: int) -> 'Node':
        return self._with_item(Item(name, value, weight, time_to_steal=tts))

    def _with_item(self, item: Item) -> 'Node':
        self.item = item
        return self

    def to_dict(self):
        try:
            return {
                'name': self.name,
                'item': self.item.name,
                'value': self.item.value,
                'weight': self.item.weight,
                'tts': self.item.tts
            }
        except Exception:
            return {
                'name': self.name,
                'item': None,
            }

    def __hash__(self) -> int:
        return self.name.__hash__()

# %%
@dataclass(frozen=True)
class Edge:
    source: Node
    destination: Node
    travelling_time: int
    travelling_cost: float

    @property
    def time(self):
        return self.travelling_time

    @property
    def cost(self):
        return self.travelling_cost

    def to_dict(self):
        return {
            'source': self.source.name,
            'destination': self.destination.name,
            'travelling_time': self.time,
            'travelling_cost': self.cost
        }

# %%
class Graph:
    nodes: Dict[str, Node]
    edges: Dict[Tuple[Node, Node], Edge]
    connections: Dict[Node, Set[Edge]]

    def __init__(self):
        self.nodes = dict()
        self.edges = dict()
        self.connections = dict()

    def get_node(self, name: str) -> Optional[Node]:
        return self.nodes.get(name)

    def get_all_nodes(self) -> List[Node]:
        return list(self.nodes.values())

    def get_all_edges(self) -> List[Edge]:
        return list(self.edges.values())

    def get_connections_from_node(self, node: Node) -> List[Edge]:
        return self.connections.get(node, {})

    def get_connections_from(self, node_name: str) -> List[Edge]:
        node: Optional[Node] = self.get_node(node_name)
        return self.get_connections_from_node(node)

    def find_connection_between(self, src: Node, dst: Node) -> Optional[Edge]:
        return self.edges.get((src, dst), None)

    def add_edge(self, src: str, dst: str, tt: int, tc: float) -> 'Graph':
        source = self.nodes.get(src, Node(src))
        destination = self.nodes.get(dst, Node(dst))
        edge = Edge(source, destination, travelling_time=tt, travelling_cost=tc)
        self._add_node(source)._add_node(destination)
        self.edges[(source, destination)] = edge
        self.connections[source] = self.connections.get(source, []) + [edge]
        return self

    def add_node(self, node_name: str) -> 'Graph':
        self.nodes[node_name] = Node(node_name)
        return self

    def _add_node(self, node: Node) -> 'Graph':
        self.nodes[node.name] = node
        return self

# %% [markdown]
# # Graph Construction

# %%
datasets_dir = Path().absolute().parent.joinpath('datasets')
travelling_map = f"{datasets_dir}/travelling_map.csv"
treasure_map = f"{datasets_dir}/treasure_map.csv"

# %%
travels = pd.read_csv(travelling_map)
treasures = pd.read_csv(treasure_map)

# %%
g = Graph()

# %%
travels.apply(lambda row: g.add_edge(src=row['source'],
                                     dst=row['destination'],
                                     tt=row['travelling_time'],
                                     tc=row['travelling_cost'])
                           .add_edge(src=row['destination'],
                                     dst=row['source'],
                                     tt=row['travelling_time'],
                                     tc=row['travelling_cost']), axis=1)

treasures.apply(lambda row: g.get_node(row['city'])
                             .with_item(row['name'],
                                        row['value'],
                                        row['weight'],
                                        row['tts']), axis=1);

# %% [markdown]
# # Problem Solving

# %%
@dataclass(frozen=False)
class Individual:
    genes: List[Node]
    extra_genes: List[Node]
    total_income: float
    travelling_cost: float
    traveling_time: int
    time_to_steal: int
    carry_weight: int
    generation: int

    @property
    def profit(self):
        return self.total_income - self.travelling_cost

    @property
    def total_time(self):
        return self.traveling_time + self.time_to_steal

    @property
    def score(self):
        return self.profit/self.total_time

    def pretty_print(self):
        names: List[str] = [gene.name for gene in self.genes]
        path: str = " -> ".join(names)
        print(f"""
        Path: {path}
        Profit: {self.profit}
        Total time: {self.total_time}
        Score: {self.score}
        Generation: {self.generation}""")

    def __eq__(self, other):
        try:
            return self.genes == other.genes
        except Exception:
            return False

    def __hash__(self):
        return sum([n.__hash__() for n in self.genes])

# %%
class GeneticAlgorithm:
    graph: Graph
    genes: Set[Node]
    max_hours: int
    max_weight: int
    rng: Generator

    def __init__(self, graph: Graph, with_max_hours: int, with_max_weight: int):
        self.graph = graph
        self.genes = list(graph.get_all_nodes())
        self.max_hours = with_max_hours
        self.max_weight = with_max_weight
        self.rng = default_rng()

    def generate_initial_batch(self, size: int = 10) -> List[Individual]:
        length = len(self.genes)
        return [self._generate_individual(length) for i in range(size)]

    def _generate_individual(self, number_of_genes: int):
        while True:
            genes, extra_genes = self._generate_individual_genes(number_of_genes)
            indv: Individual = self.generate_individual_with(genes=genes, extra_genes=extra_genes)

            if indv == None:
                continue

            if self.fitness(indv) > 0:
                return indv

    def _generate_individual_genes(self, number: int) -> Tuple[List[Node], List[Node]]:
        indexes: List[int] = self.rng.choice(number, size=number, replace=False)
        genes: List[Node] = [self.genes[idx] for idx in indexes]

        starting_point: Node = self.graph.get_node("Escondidos")
        endpoint_idx: int = genes.index(starting_point)

        individual_genes: List[Node] = [starting_point] + genes[0:endpoint_idx+1]
        extra_genes: List[Node] = genes[endpoint_idx+1:]
        return individual_genes, extra_genes

    def generate_individual_with(self, genes, extra_genes, generation: int = 0):
        tuples: List[Tuple[Node, Node]] = [(genes[idx], genes[num]) for idx, num in enumerate(range(1, len(genes)))]
        connections: List[Edge] = [self.graph.find_connection_between(src, dest) for src, dest in tuples if (src != dest)]

        if len(connections) == 0:
            return None

        travelling_cost: float = 0.0
        travelling_time: int = 0
        total_income: float = 0.0
        time_to_steal: int = 0
        total_weight: int = 0

        for cx in connections:
            travelling_cost += cx.travelling_cost
            travelling_time += cx.travelling_time
            total_income += cx.destination.to_dict().get('value', 0)
            time_to_steal += cx.destination.to_dict().get('tts', 0)
            total_weight += cx.destination.to_dict().get('weight', 0)

        indv = Individual(genes, total_income=total_income, time_to_steal=time_to_steal,
                          travelling_cost=travelling_cost, traveling_time=travelling_time,
                          carry_weight=total_weight, extra_genes=extra_genes,
                          generation=generation)
        return indv


    def fitness(self, indv: Individual) -> int:
        if indv.carry_weight > self.max_weight or indv.total_time > self.max_hours:
            return 0

        return indv.score

    def mutate(self, indv: Individual) -> Optional[Individual]:
        left: List[Node] = list(indv.genes)
        right: List[Node] = list(indv.extra_genes)

        left_idx: int = random.randint(1, len(left)-2)
        right_idx: int = random.randint(0, len(right)-1)

        tmp = left[left_idx]
        left[left_idx] = right[right_idx]
        right[right_idx] = tmp

        new_indv = self.generate_individual_with(genes=left, 
                                                 extra_genes=right, 
                                                 generation=indv.generation+1)
        if self.fitness(new_indv) > 0:
            return new_indv

        return None


    def cross_over(self, indvA: Individual, indvB: Individual) -> List[Individual]:
        if indvA is None or indvB is None:
            return []

        gene = [self.graph.get_node('Escondidos')]
        next_gen = max(indvA.generation, indvB.generation)+1

        indvC = self.generate_individual_with(genes=list(gene + indvB.extra_genes + gene),
                                              extra_genes=list(indvA.genes[1:-1]),
                                              generation = next_gen)

        indvD = self.generate_individual_with(genes=list(gene + indvA.extra_genes + gene),
                                              extra_genes=list(indvA.genes[1:-1]), 
                                              generation = next_gen)

        cross_over_population = list()

        if self.fitness(indvC) > 0:
            cross_over_population.append(indvC)

        if self.fitness(indvD) > 0:
            cross_over_population.append(indvC)

        return cross_over_population

# %%
ga = GeneticAlgorithm(g, with_max_hours=72, with_max_weight=20)

# %%
population = ga.generate_initial_batch(size=100)

# %%
for i in range(10):
    new_population = list()

    for idx, indv in enumerate(population[:-1]):
        a = indv
        b = population[idx+1]
        a_mut = ga.mutate(a)
        b_mut = ga.mutate(b)

        new_population += ga.cross_over(a, b)
        new_population += ga.cross_over(a, b_mut)
        new_population += ga.cross_over(a_mut, b)
        new_population += ga.cross_over(a_mut, b_mut)

    population += new_population
    population = sorted(set(population), key=lambda indv: indv.score, reverse=True)

# %%
len(population)
# Out:
# 515

# %%
for p in population[0:100]:
    p.pretty_print()
# Out:
#         Path: Escondidos -> Riacho de Fevereiro -> Escondidos
#         Profit: 6870.0
#         Total time: 8
#         Score: 858.75
#         Generation: 0
#
#         Path: Escondidos -> Limões -> Riacho de Fevereiro -> Escondidos
#         Profit: 10344.0
#         Total time: 19
#         Score: 544.421052631579
#         Generation: 10
#
#         Path: Escondidos -> Leão -> Riacho de Fevereiro -> Escondidos
#         Profit: 10213.0
#         Total time: 19
#         Score: 537.5263157894736
#         Generation: 0
#
#         Path: Escondidos -> Porto -> Santa Paula -> Granada -> Limões -> Riacho de Fevereiro -> Leão -> Riacho de Fevereiro -> Escondidos
#         Profit: 33697.0
#         Total time: 66
#         Score: 510.56060606060606
#         Generation: 10
#
#         Path: Escondidos -> Limões -> Granada -> Leão -> Campos -> Escondidos
#         Profit: 15589.0
#         Total time: 31
#         Score: 502.8709677419355
#         Generation: 0
#
#         Path: Escondidos -> Porto -> Porto -> Riacho de Fevereiro -> Escondidos
#         Profit: 8451.0
#         Total time: 17
#         Score: 497.11764705882354
#         Generation: 14
#
#         Path: Escondidos -> Riacho de Fevereiro -> Porto -> Escondidos
#         Profit: 8451.0
#         Total time: 17
#         Score: 497.11764705882354
#         Generation: 0
#
#         Path: Escondidos -> Riacho de Fevereiro -> Campos -> Santa Paula -> Foz da Água Quente -> Porto -> Escondidos
#         Profit: 24913.0
#         Total time: 51
#         Score: 488.4901960784314
#         Generation: 0
#
#         Path: Escondidos -> Campos -> Além-do-Mar -> Santa Paula -> Santa Paula -> Granada -> Limões -> Escondidos
#         Profit: 26199.0
#         Total time: 54
#         Score: 485.1666666666667
#         Generation: 9
#
#         Path: Escondidos -> Riacho de Fevereiro -> Santa Paula -> Santa Paula -> Escondidos
#         Profit: 14963.0
#         Total time: 31
#         Score: 482.6774193548387
#         Generation: 12
#
#         Path: Escondidos -> Santa Paula -> Riacho de Fevereiro -> Escondidos
#         Profit: 14963.0
#         Total time: 31
#         Score: 482.6774193548387
#         Generation: 14
#
#         Path: Escondidos -> Riacho de Fevereiro -> Campos -> Santa Paula -> Porto -> Granada -> Limões -> Lagos -> Além-do-Mar -> Leão -> Escondidos
#         Profit: 41020.0
#         Total time: 85
#         Score: 482.5882352941176
#         Generation: 11
#
#         Path: Escondidos -> Campos -> Além-do-Mar -> Riacho de Fevereiro -> Santa Paula -> Granada -> Limões -> Escondidos
#         Profit: 32427.0
#         Total time: 68
#         Score: 476.86764705882354
#         Generation: 10
#
#         Path: Escondidos -> Riacho de Fevereiro -> Santa Paula -> Granada -> Escondidos
#         Profit: 17582.0
#         Total time: 37
#         Score: 475.18918918918916
#         Generation: 6
#
#         Path: Escondidos -> Porto -> Riacho de Fevereiro -> Limões -> Foz da Água Quente -> Além-do-Mar -> Campos -> Escondidos
#         Profit: 25183.0
#         Total time: 54
#         Score: 466.35185185185185
#         Generation: 7
#
#         Path: Escondidos -> Além-do-Mar -> Santa Paula -> Campos -> Leão -> Escondidos
#         Profit: 23761.0
#         Total time: 51
#         Score: 465.9019607843137
#         Generation: 11
#
#         Path: Escondidos -> Campos -> Riacho de Fevereiro -> Campos -> Escondidos
#         Profit: 17644.0
#         Total time: 38
#         Score: 464.3157894736842
#         Generation: 8
#
#         Path: Escondidos -> Campos -> Além-do-Mar -> Porto -> Santa Paula -> Granada -> Limões -> Escondidos
#         Profit: 28196.0
#         Total time: 61
#         Score: 462.2295081967213
#         Generation: 10
#
#         Path: Escondidos -> Leão -> Riacho de Fevereiro -> Campos -> Escondidos
#         Profit: 15600.0
#         Total time: 34
#         Score: 458.8235294117647
#         Generation: 0
#
#         Path: Escondidos -> Campos -> Além-do-Mar -> Lagos -> Santa Paula -> Granada -> Limões -> Escondidos
#         Profit: 29320.0
#         Total time: 64
#         Score: 458.125
#         Generation: 4
#
#         Path: Escondidos -> Leão -> Riacho de Fevereiro -> Leão -> Escondidos
#         Profit: 13556.0
#         Total time: 30
#         Score: 451.8666666666667
#         Generation: 8
#
#         Path: Escondidos -> Campos -> Riacho de Fevereiro -> Limões -> Foz da Água Quente -> Além-do-Mar -> Santa Paula -> Escondidos
#         Profit: 31397.0
#         Total time: 70
#         Score: 448.5285714285714
#         Generation: 7
#
#         Path: Escondidos -> Santa Paula -> Além-do-Mar -> Santa Paula -> Santa Paula -> Granada -> Limões -> Escondidos
#         Profit: 28607.0
#         Total time: 64
#         Score: 446.984375
#         Generation: 16
#
#         Path: Escondidos -> Leão -> Santa Paula -> Campos -> Escondidos
#         Profit: 18730.0
#         Total time: 42
#         Score: 445.95238095238096
#         Generation: 8
#
#         Path: Escondidos -> Riacho de Fevereiro -> Algas -> Santa Paula -> Escondidos
#         Profit: 17800.0
#         Total time: 40
#         Score: 445.0
#         Generation: 9
#
#         Path: Escondidos -> Porto -> Santa Paula -> Granada -> Limões -> Riacho de Fevereiro -> Limões -> Foz da Água Quente -> Escondidos
#         Profit: 28921.0
#         Total time: 65
#         Score: 444.9384615384615
#         Generation: 10
#
#         Path: Escondidos -> Leão -> Riacho de Fevereiro -> Limões -> Foz da Água Quente -> Além-do-Mar -> Santa Paula -> Escondidos
#         Profit: 29353.0
#         Total time: 66
#         Score: 444.74242424242425
#         Generation: 12
#
#         Path: Escondidos -> Além-do-Mar -> Campos -> Lagos -> Leão -> Escondidos
#         Profit: 17746.0
#         Total time: 40
#         Score: 443.65
#         Generation: 11
#
#         Path: Escondidos -> Riacho de Fevereiro -> Santa Paula -> Limões -> Escondidos
#         Profit: 18632.0
#         Total time: 42
#         Score: 443.6190476190476
#         Generation: 9
#
#         Path: Escondidos -> Riacho de Fevereiro -> Santa Paula -> Granada -> Limões -> Riacho de Fevereiro -> Leão -> Foz da Água Quente -> Escondidos
#         Profit: 32678.0
#         Total time: 74
#         Score: 441.5945945945946
#         Generation: 10
#
#         Path: Escondidos -> Leão -> Granada -> Limões -> Foz da Água Quente -> Além-do-Mar -> Santa Paula -> Escondidos
#         Profit: 25153.0
#         Total time: 57
#         Score: 441.280701754386
#         Generation: 10
#
#         Path: Escondidos -> Campos -> Além-do-Mar -> Algas -> Santa Paula -> Granada -> Limões -> Escondidos
#         Profit: 28669.0
#         Total time: 65
#         Score: 441.0615384615385
#         Generation: 9
#
#         Path: Escondidos -> Campos -> Além-do-Mar -> Limões -> Santa Paula -> Granada -> Limões -> Escondidos
#         Profit: 29484.0
#         Total time: 67
#         Score: 440.05970149253733
#         Generation: 10
#
#         Path: Escondidos -> Riacho de Fevereiro -> Leão -> Foz da Água Quente -> Porto -> Santa Paula -> Campos -> Leão -> Guardião -> Algas -> Limões -> Escondidos
#         Profit: 40909.0
#         Total time: 93
#         Score: 439.8817204301075
#         Generation: 6
#
#         Path: Escondidos -> Riacho de Fevereiro -> Granada -> Limões -> Foz da Água Quente -> Além-do-Mar -> Santa Paula -> Escondidos
#         Profit: 27540.0
#         Total time: 63
#         Score: 437.14285714285717
#         Generation: 10
#
#         Path: Escondidos -> Limões -> Lagos -> Granada -> Porto -> Santa Paula -> Riacho de Fevereiro -> Escondidos
#         Profit: 25599.0
#         Total time: 59
#         Score: 433.8813559322034
#         Generation: 5
#
#         Path: Escondidos -> Porto -> Riacho de Fevereiro -> Campos -> Escondidos
#         Profit: 13838.0
#         Total time: 32
#         Score: 432.4375
#         Generation: 8
#
#         Path: Escondidos -> Porto -> Riacho de Fevereiro -> Limões -> Foz da Água Quente -> Além-do-Mar -> Santa Paula -> Escondidos
#         Profit: 27591.0
#         Total time: 64
#         Score: 431.109375
#         Generation: 1
#
#         Path: Escondidos -> Campos -> Além-do-Mar -> Guardião -> Santa Paula -> Granada -> Limões -> Escondidos
#         Profit: 28453.0
#         Total time: 66
#         Score: 431.1060606060606
#         Generation: 3
#
#         Path: Escondidos -> Riacho de Fevereiro -> Santa Paula -> Além-do-Mar -> Escondidos
#         Profit: 19828.0
#         Total time: 46
#         Score: 431.04347826086956
#         Generation: 6
#
#         Path: Escondidos -> Porto -> Riacho de Fevereiro -> Limões -> Escondidos
#         Profit: 11925.0
#         Total time: 28
#         Score: 425.89285714285717
#         Generation: 8
#
#         Path: Escondidos -> Campos -> Foz da Água Quente -> Santa Paula -> Porto -> Granada -> Limões -> Lagos -> Além-do-Mar -> Leão -> Escondidos
#         Profit: 35967.0
#         Total time: 85
#         Score: 423.1411764705882
#         Generation: 11
#
#         Path: Escondidos -> Riacho de Fevereiro -> Leão -> Foz da Água Quente -> Porto -> Santa Paula -> Campos -> Granada -> Guardião -> Algas -> Riacho de Fevereiro -> Escondidos
#         Profit: 41872.0
#         Total time: 99
#         Score: 422.949494949495
#         Generation: 9
#
#         Path: Escondidos -> Leão -> Riacho de Fevereiro -> Porto -> Escondidos
#         Profit: 11794.0
#         Total time: 28
#         Score: 421.2142857142857
#         Generation: 8
#
#         Path: Escondidos -> Limões -> Riacho de Fevereiro -> Leão -> Santa Paula -> Escondidos
#         Profit: 22263.0
#         Total time: 53
#         Score: 420.0566037735849
#         Generation: 4
#
#         Path: Escondidos -> Granada -> Além-do-Mar -> Leão -> Riacho de Fevereiro -> Escondidos
#         Profit: 17207.0
#         Total time: 41
#         Score: 419.6829268292683
#         Generation: 0
#
#         Path: Escondidos -> Algas -> Foz da Água Quente -> Santa Paula -> Porto -> Granada -> Limões -> Riacho de Fevereiro -> Além-do-Mar -> Leão -> Escondidos
#         Profit: 36504.0
#         Total time: 87
#         Score: 419.58620689655174
#         Generation: 5
#
#         Path: Escondidos -> Granada -> Santa Paula -> Foz da Água Quente -> Riacho de Fevereiro -> Leão -> Guardião -> Além-do-Mar -> Campos -> Escondidos
#         Profit: 36062.0
#         Total time: 86
#         Score: 419.3255813953488
#         Generation: 2
#
#         Path: Escondidos -> Porto -> Santa Paula -> Granada -> Riacho de Fevereiro -> Algas -> Campos -> Escondidos
#         Profit: 27548.0
#         Total time: 66
#         Score: 417.3939393939394
#         Generation: 3
#
#         Path: Escondidos -> Campos -> Além-do-Mar -> Lagos -> Santa Paula -> Algas -> Limões -> Escondidos
#         Profit: 29210.0
#         Total time: 70
#         Score: 417.2857142857143
#         Generation: 9
#
#         Path: Escondidos -> Além-do-Mar -> Santa Paula -> Lagos -> Riacho de Fevereiro -> Escondidos
#         Profit: 23307.0
#         Total time: 56
#         Score: 416.19642857142856
#         Generation: 14
#
#         Path: Escondidos -> Porto -> Riacho de Fevereiro -> Campos -> Foz da Água Quente -> Além-do-Mar -> Santa Paula -> Escondidos
#         Profit: 29126.0
#         Total time: 70
#         Score: 416.0857142857143
#         Generation: 3
#
#         Path: Escondidos -> Riacho de Fevereiro -> Leão -> Limões -> Escondidos
#         Profit: 13292.0
#         Total time: 32
#         Score: 415.375
#         Generation: 8
#
#         Path: Escondidos -> Limões -> Leão -> Riacho de Fevereiro -> Escondidos
#         Profit: 13292.0
#         Total time: 32
#         Score: 415.375
#         Generation: 14
#
#         Path: Escondidos -> Riacho de Fevereiro -> Foz da Água Quente -> Santa Paula -> Porto -> Granada -> Limões -> Algas -> Além-do-Mar -> Leão -> Escondidos
#         Profit: 35699.0
#         Total time: 86
#         Score: 415.1046511627907
#         Generation: 11
#
#         Path: Escondidos -> Porto -> Santa Paula -> Granada -> Porto -> Riacho de Fevereiro -> Leão -> Foz da Água Quente -> Escondidos
#         Profit: 26968.0
#         Total time: 65
#         Score: 414.89230769230767
#         Generation: 5
#
#         Path: Escondidos -> Leão -> Além-do-Mar -> Guardião -> Santa Paula -> Granada -> Limões -> Escondidos
#         Profit: 26138.0
#         Total time: 63
#         Score: 414.8888888888889
#         Generation: 0
#
#         Path: Escondidos -> Foz da Água Quente -> Santa Paula -> Granada -> Riacho de Fevereiro -> Algas -> Campos -> Escondidos
#         Profit: 27362.0
#         Total time: 66
#         Score: 414.57575757575756
#         Generation: 0
#
#         Path: Escondidos -> Riacho de Fevereiro -> Foz da Água Quente -> Santa Paula -> Porto -> Granada -> Limões -> Lagos -> Além-do-Mar -> Leão -> Escondidos
#         Profit: 35972.0
#         Total time: 87
#         Score: 413.4712643678161
#         Generation: 3
#
#         Path: Escondidos -> Porto -> Riacho de Fevereiro -> Limões -> Foz da Água Quente -> Além-do-Mar -> Limões -> Escondidos
#         Profit: 22245.0
#         Total time: 54
#         Score: 411.94444444444446
#         Generation: 7
#
#         Path: Escondidos -> Limões -> Riacho de Fevereiro -> Porto -> Guardião -> Campos -> Santa Paula -> Algas -> Escondidos
#         Profit: 31718.0
#         Total time: 77
#         Score: 411.9220779220779
#         Generation: 3
#
#         Path: Escondidos -> Lagos -> Riacho de Fevereiro -> Escondidos
#         Profit: 9059.0
#         Total time: 22
#         Score: 411.77272727272725
#         Generation: 7
#
#         Path: Escondidos -> Campos -> Riacho de Fevereiro -> Lagos -> Santa Paula -> Limões -> Escondidos
#         Profit: 27498.0
#         Total time: 67
#         Score: 410.4179104477612
#         Generation: 0
#
#         Path: Escondidos -> Lagos -> Riacho de Fevereiro -> Limões -> Foz da Água Quente -> Além-do-Mar -> Santa Paula -> Escondidos
#         Profit: 28199.0
#         Total time: 69
#         Score: 408.6811594202899
#         Generation: 3
#
#         Path: Escondidos -> Lagos -> Algas -> Santa Paula -> Foz da Água Quente -> Campos -> Além-do-Mar -> Leão -> Escondidos
#         Profit: 30519.0
#         Total time: 75
#         Score: 406.92
#         Generation: 6
#
#         Path: Escondidos -> Foz da Água Quente -> Além-do-Mar -> Riacho de Fevereiro -> Leão -> Guardião -> Lagos -> Ponte-do-Sol -> Campos -> Santa Paula -> Porto -> Escondidos
#         Profit: 40679.0
#         Total time: 100
#         Score: 406.79
#         Generation: 5
#
#         Path: Escondidos -> Além-do-Mar -> Santa Paula -> Granada -> Riacho de Fevereiro -> Algas -> Campos -> Escondidos
#         Profit: 30277.0
#         Total time: 75
#         Score: 403.6933333333333
#         Generation: 4
#
#         Path: Escondidos -> Além-do-Mar -> Campos -> Escondidos
#         Profit: 10897.0
#         Total time: 27
#         Score: 403.5925925925926
#         Generation: 0
#
#         Path: Escondidos -> Riacho de Fevereiro -> Foz da Água Quente -> Santa Paula -> Porto -> Granada -> Limões -> Lagos -> Lagos -> Leão -> Escondidos
#         Profit: 30669.0
#         Total time: 76
#         Score: 403.5394736842105
#         Generation: 11
#
#         Path: Escondidos -> Santa Paula -> Ponte-do-Sol -> Algas -> Campos -> Leão -> Guardião -> Limões -> Escondidos
#         Profit: 27998.0
#         Total time: 70
#         Score: 399.9714285714286
#         Generation: 12
#
#         Path: Escondidos -> Riacho de Fevereiro -> Leão -> Foz da Água Quente -> Porto -> Santa Paula -> Campos -> Granada -> Guardião -> Algas -> Limões -> Escondidos
#         Profit: 38729.0
#         Total time: 97
#         Score: 399.2680412371134
#         Generation: 3
#
#         Path: Escondidos -> Porto -> Santa Paula -> Granada -> Limões -> Riacho de Fevereiro -> Leão -> Foz da Água Quente -> Escondidos
#         Profit: 28291.0
#         Total time: 71
#         Score: 398.46478873239437
#         Generation: 2
#
#         Path: Escondidos -> Santa Paula -> Limões -> Granada -> Riacho de Fevereiro -> Campos -> Escondidos
#         Profit: 25892.0
#         Total time: 65
#         Score: 398.33846153846156
#         Generation: 9
#
#         Path: Escondidos -> Limões -> Além-do-Mar -> Limões -> Santa Paula -> Granada -> Limões -> Escondidos
#         Profit: 26546.0
#         Total time: 67
#         Score: 396.2089552238806
#         Generation: 13
#
#         Path: Escondidos -> Santa Paula -> Santa Paula -> Granada -> Escondidos
#         Profit: 11059.0
#         Total time: 28
#         Score: 394.9642857142857
#         Generation: 7
#
#         Path: Escondidos -> Granada -> Santa Paula -> Santa Paula -> Escondidos
#         Profit: 11059.0
#         Total time: 28
#         Score: 394.9642857142857
#         Generation: 5
#
#         Path: Escondidos -> Campos -> Campos -> Ponte-do-Sol -> Leão -> Escondidos
#         Profit: 11044.0
#         Total time: 28
#         Score: 394.42857142857144
#         Generation: 6
#
#         Path: Escondidos -> Campos -> Além-do-Mar -> Algas -> Santa Paula -> Santa Paula -> Limões -> Escondidos
#         Profit: 26011.0
#         Total time: 66
#         Score: 394.1060606060606
#         Generation: 12
#
#         Path: Escondidos -> Algas -> Santa Paula -> Granada -> Riacho de Fevereiro -> Campos -> Escondidos
#         Profit: 25190.0
#         Total time: 64
#         Score: 393.59375
#         Generation: 9
#
#         Path: Escondidos -> Limões -> Lagos -> Granada -> Santa Paula -> Guardião -> Riacho de Fevereiro -> Escondidos
#         Profit: 26357.0
#         Total time: 67
#         Score: 393.3880597014925
#         Generation: 5
#
#         Path: Escondidos -> Limões -> Santa Paula -> Granada -> Limões -> Riacho de Fevereiro -> Leão -> Foz da Água Quente -> Escondidos
#         Profit: 29824.0
#         Total time: 76
#         Score: 392.42105263157896
#         Generation: 5
#
#         Path: Escondidos -> Riacho de Fevereiro -> Santa Paula -> Algas -> Escondidos
#         Profit: 17215.0
#         Total time: 44
#         Score: 391.25
#         Generation: 6
#
#         Path: Escondidos -> Campos -> Além-do-Mar -> Guardião -> Santa Paula -> Porto -> Limões -> Escondidos
#         Profit: 28112.0
#         Total time: 72
#         Score: 390.44444444444446
#         Generation: 10
#
#         Path: Escondidos -> Riacho de Fevereiro -> Algas -> Foz da Água Quente -> Santa Paula -> Além-do-Mar -> Granada -> Escondidos
#         Profit: 26511.0
#         Total time: 68
#         Score: 389.86764705882354
#         Generation: 0
#
#         Path: Escondidos -> Riacho de Fevereiro -> Santa Paula -> Ponte-do-Sol -> Escondidos
#         Profit: 16349.0
#         Total time: 42
#         Score: 389.26190476190476
#         Generation: 0
#
#         Path: Escondidos -> Porto -> Granada -> Limões -> Foz da Água Quente -> Além-do-Mar -> Santa Paula -> Escondidos
#         Profit: 22900.0
#         Total time: 59
#         Score: 388.135593220339
#         Generation: 2
#
#         Path: Escondidos -> Campos -> Além-do-Mar -> Ponte-do-Sol -> Leão -> Escondidos
#         Profit: 16246.0
#         Total time: 42
#         Score: 386.8095238095238
#         Generation: 6
#
#         Path: Escondidos -> Campos -> Escondidos
#         Profit: 5800.0
#         Total time: 15
#         Score: 386.6666666666667
#         Generation: 0
#
#         Path: Escondidos -> Granada -> Riacho de Fevereiro -> Lagos -> Campos -> Escondidos
#         Profit: 17012.0
#         Total time: 44
#         Score: 386.6363636363636
#         Generation: 0
#
#         Path: Escondidos -> Limões -> Além-do-Mar -> Guardião -> Santa Paula -> Granada -> Limões -> Escondidos
#         Profit: 25515.0
#         Total time: 66
#         Score: 386.59090909090907
#         Generation: 10
#
#         Path: Escondidos -> Limões -> Riacho de Fevereiro -> Ponte-do-Sol -> Guardião -> Campos -> Santa Paula -> Algas -> Escondidos
#         Profit: 30528.0
#         Total time: 79
#         Score: 386.43037974683546
#         Generation: 3
#
#         Path: Escondidos -> Porto -> Santa Paula -> Granada -> Limões -> Riacho de Fevereiro -> Lagos -> Foz da Água Quente -> Escondidos
#         Profit: 27431.0
#         Total time: 71
#         Score: 386.3521126760563
#         Generation: 5
#
#         Path: Escondidos -> Santa Paula -> Ponte-do-Sol -> Além-do-Mar -> Campos -> Granada -> Guardião -> Limões -> Escondidos
#         Profit: 28957.0
#         Total time: 75
#         Score: 386.0933333333333
#         Generation: 12
#
#         Path: Escondidos -> Porto -> Santa Paula -> Granada -> Limões -> Riacho de Fevereiro -> Leão -> Porto -> Escondidos
#         Profit: 28174.0
#         Total time: 73
#         Score: 385.94520547945206
#         Generation: 10
#
#         Path: Escondidos -> Porto -> Riacho de Fevereiro -> Leão -> Foz da Água Quente -> Além-do-Mar -> Santa Paula -> Escondidos
#         Profit: 26961.0
#         Total time: 70
#         Score: 385.15714285714284
#         Generation: 7
#
#         Path: Escondidos -> Limões -> Riacho de Fevereiro -> Além-do-Mar -> Guardião -> Campos -> Santa Paula -> Algas -> Escondidos
#         Profit: 34240.0
#         Total time: 89
#         Score: 384.7191011235955
#         Generation: 3
#
#         Path: Escondidos -> Santa Paula -> Lagos -> Granada -> Porto -> Algas -> Riacho de Fevereiro -> Escondidos
#         Profit: 24501.0
#         Total time: 64
#         Score: 382.828125
#         Generation: 8
#
#         Path: Escondidos -> Ponte-do-Sol -> Algas -> Santa Paula -> Riacho de Fevereiro -> Campos -> Além-do-Mar -> Leão -> Escondidos
#         Profit: 33285.0
#         Total time: 87
#         Score: 382.58620689655174
#         Generation: 9
#
#         Path: Escondidos -> Santa Paula -> Lagos -> Granada -> Porto -> Guardião -> Riacho de Fevereiro -> Escondidos
#         Profit: 24827.0
#         Total time: 65
#         Score: 381.95384615384614
#         Generation: 5
#
#         Path: Escondidos -> Leão -> Ponte-do-Sol -> Além-do-Mar -> Riacho de Fevereiro -> Porto -> Santa Paula -> Lagos -> Escondidos
#         Profit: 30487.0
#         Total time: 80
#         Score: 381.0875
#         Generation: 7
